# %% [markdown]
# # Elements and the periodic table
#
# This activity allows various properties of elements to be visualized in a scatterplot.
#
# To get started,
# - First, click the disc icon at the top to save the notebook. That makes it easier to start over later if you need to.
# - Go to the menu bar above and select **Kernel > Restart & Run All**.
# - You won't hurt anything by experimenting. If you break it, go to **File > Revert to checkpoint** to start over.
# - Is this your first time? Need a refresher? Try the 5-minute [Intro to Jupyter activity](./Intro_to_Jupyter.ipynb) and come back here.
#
# When you're ready, scroll down to **Part One**.

# %%
# Import modules that contain functions we need
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Read in data that will be used for the calculations.
data = pd.read_csv("http://github.com/adamlamee/CODINGinK12-data/raw/master/elements.csv")

# %%
# displays the first 5 rows of the data set
data.head(5)
# Out:
#    AtomicNumber Symbol        Name  AtomicMass  AtomicRadius  IonRadius  \
# 0             1     H     Hydrogen    1.007940          37.0        NaN
# 1             2    He       Helium    4.002602          32.0        NaN
# 2             3    Li      Lithium    6.941000         134.0       76.0
# 3             4    Be    Beryllium    9.012182          90.0       45.0
# 4             5     B        Boron   10.811000          82.0       27.0
#
#     Color ElectronicConfiguration  Electronegativity  VdWRadius  \
# 0  FFFFFF                    1s1                2.20      120.0
# 1  D9FFFF                    1s2                0.00      140.0
# 2  CC80FF               [He] 2s1                0.98      182.0
# 3  C2FF00               [He] 2s2                1.57        NaN
# 4  FFB5B5           [He] 2s2 2p1                2.04        NaN
#
#    IE-1 (kJ/mol)  EA (kJ/mol) Oxidation States StandardState  \
# 0         1312.0        -73.0            -1, 1           gas
# 1         2372.0          0.0              NaN           gas
# 2          520.0        -60.0                1         solid
# 3          900.0          0.0                2         solid
# 4          801.0        -27.0          1, 2, 3         solid
#
#         BondingType MeltingPoint BoilingPoint   Density                  Type  \
# 0          diatomic           14           20  8.99E-05              nonmetal
# 1            atomic          NaN            4         0             noble gas
# 2          metallic          454         1615      0.54          alkali metal
# 3          metallic         1560         2743      1.85  alkaline earth metal
# 4  covalent network         2348         4273      2.46             metalloid
#
#   YearDiscovered
# 0           1766
# 1           1868
# 2           1817
# 3           1798
# 4           1807

# %%
# the names of all the columns in the dataset
data.columns
# Out:
# Index(['AtomicNumber', 'Symbol', 'Name', 'AtomicMass', 'AtomicRadius',
#        'IonRadius', 'Color', 'ElectronicConfiguration', 'Electronegativity',
#        'VdWRadius', 'IE-1 (kJ/mol)', 'EA (kJ/mol)', 'Oxidation States',
#        'StandardState', 'BondingType', 'MeltingPoint', 'BoilingPoint',
#        'Density', 'Type', 'YearDiscovered'],
#       dtype='object')

# %%
# The .shape command displays the (number of rows , number of columns) in a file.
data.shape
# Out:
# (118, 20)

# %% [markdown]
# ## Part One
# Let's get acquainted with this data set. Look at the cells above to find the answers to the following questions:
# - In the table above, what do you think each of the column headings represent?
# - How many elements are included in this data set?
#
# When you're ready, scroll down to **Part Two**.

# %%
ax = data.plot('AtomicNumber', 'AtomicRadius', title="something vs. something else", legend=False)
ax.set(xlabel="x label", ylabel="y label")
# Out:
# [<matplotlib.text.Text at 0x1160f75c0>, <matplotlib.text.Text at 0x1160f7080>]

# %% [markdown]
# ## Part Two
# The code above generates a graph of Atomic Number vs. Atomic Radius.
# - The title and axis labels on the graph could use some work. Try editing the code above the graph, then run the code again to see the changes.
# - What pattern do you see in the graph? What might explain that pattern?
# - Now, graph a different relationship. There are lots of options, just look at all the columns in the data table. Just be sure to typ the column name exactly as it appears in the table. Coding is case-sensitive and sometimes doesn't like extra spaces.
#
# When you're ready, scroll down to **Part Three**.

# %%
data.sort_values(by='YearDiscovered', ascending=True)
# Out:
#      AtomicNumber Symbol           Name  AtomicMass  AtomicRadius  IonRadius  \
# 14             15     P      Phosphorus   30.973762         106.0       44.0
# 8               9     F        Fluorine   18.998403          71.0      133.0
# 29             30    Zn            Zinc   65.380000         131.0       74.0
# 27             28    Ni          Nickel   58.693400         121.0       69.0
# 0               1     H        Hydrogen    1.007940          37.0        NaN
# 6               7     N        Nitrogen   14.006700          75.0      146.0
# 7               8     O          Oxygen   15.999400          73.0      140.0
# 24             25    Mn       Manganese   54.938045         139.0       67.0
# 16             17    Cl        Chlorine   35.453000          99.0      181.0
# 41             42    Mo      Molybdenum   95.960000         145.0       69.0
# 51             52    Te       Tellurium  127.600000         135.0      221.0
# 73             74     W        Tungsten  183.840000         146.0       66.0
# 91             92     U         Uranium  238.028910           NaN      102.5
# 39             40    Zr       Zirconium   91.224000         148.0       72.0
# 37             38    Sr       Strontium   87.620000         192.0      118.0
# 21             22    Ti        Titanium   47.867000         136.0       86.0
# 38             39     Y         Yttrium   88.905850         162.0       90.0
# 3               4    Be       Beryllium    9.012182          90.0       45.0
# 40             41    Nb         Niobium   92.906380         137.0       72.0
# 72             73    Ta        Tantalum  180.947880         138.0       72.0
# 75             76    Os          Osmium  190.230000         128.0       63.0
# 44             45    Rh         Rhodium  102.905500         135.0       66.5
# 57             58    Ce          Cerium  140.116000           NaN      102.0
# 45             46    Pd       Palladium  106.420000         131.0       59.0
# 22             23     V        Vanadium   50.941500         125.0       79.0
# 76             77    Ir         Iridium  192.217000         137.0       68.0
# 4               5     B           Boron   10.811000          82.0       27.0
# 18             19     K       Potassium   39.098300         196.0      138.0
# 10             11    Na          Sodium   22.989769         154.0      102.0
# 11             12    Mg       Magnesium   24.305000         130.0       72.0
# ..            ...    ...            ...         ...           ...        ...
# 105           106    Sg      Seaborgium         NaN           NaN        NaN
# 106           107    Bh         Bohrium         NaN           NaN        NaN
# 108           109    Mt      Meitnerium         NaN           NaN        NaN
# 107           108    Hs         Hassium         NaN           NaN        NaN
# 109           110    Ds    Darmstadtium         NaN           NaN        NaN
# 110           111    Rg     Roentgenium         NaN           NaN        NaN
# 111           112    Cn     Copernicium         NaN           NaN        NaN
# 113           114   Uuq     Ununquadium         NaN           NaN        NaN
# 115           116   Uuh      Ununhexium         NaN           NaN        NaN
# 117           118   Uuo     Ununoctium          NaN           NaN        NaN
# 114           115   Uup     Ununpentium         NaN           NaN        NaN
# 112           113   Uut       Ununtrium         NaN           NaN        NaN
# 116           117   Uus     Ununseptium         NaN           NaN        NaN
# 82             83    Bi         Bismuth  208.980400         146.0      103.0
# 49             50    Sn             Tin  118.710000         141.0      112.0
# 46             47    Ag          Silver  107.868200         153.0      115.0
# 32             33    As         Arsenic   74.921600         119.0       58.0
# 28             29    Cu          Copper   63.546000         138.0       77.0
# 26             27    Co          Cobalt   58.933195         126.0       74.5
# 25             26    Fe            Iron   55.845000         125.0       78.0
# 23             24    Cr        Chromium   51.996100         127.0       80.0
# 19             20    Ca         Calcium   40.078000         174.0      100.0
# 15             16     S          Sulfur   32.065000         102.0      184.0
# 77             78    Pt        Platinum  195.084000         128.0       86.0
# 78             79    Au            Gold  196.966569         144.0      137.0
# 79             80    Hg         Mercury  200.590000         149.0      119.0
# 12             13    Al        Aluminum   26.981539         118.0       53.5
# 81             82    Pb            Lead  207.200000         147.0      119.0
# 5               6     C          Carbon   12.010700          77.0       16.0
# 50             51    Sb        Antimony  121.760000         138.0       76.0
#
#         Color  ElectronicConfiguration  Electronegativity  VdWRadius  \
# 14     FF8000            [Ne] 3s2 3p3                2.19      180.0
# 8    9.00E+51            [He] 2s2 2p5                3.98      147.0
# 29     7D80B0           [Ar] 3d10 4s2                1.65      139.0
# 27     50D050            [Ar] 3d8 4s2                1.91      163.0
# 0      FFFFFF                     1s1                2.20      120.0
# 6      3050F8            [He] 2s2 2p3                3.04      155.0
# 7      FF0D0D            [He] 2s2 2p4                3.44      152.0
# 24     9C7AC7            [Ar] 3d5 4s2                1.55        NaN
# 16     1FF01F            [Ne] 3s2 3p5                3.16      175.0
# 41     54B5B5            [Kr] 4d5 5s1                2.16        NaN
# 51     D47A00       [Kr] 4d10 5s2 5p4                2.10      206.0
# 73     2194D6       [Xe] 4f14 5d4 6s2                2.36        NaN
# 91     008FFF        [Rn] 5f3 6d1 7s2                1.38      186.0
# 39     94E0E0            [Kr] 4d2 5s2                1.33        NaN
# 37     00FF00                [Kr] 5s2                0.95        NaN
# 21     BFC2C7            [Ar] 3d2 4s2                1.54        NaN
# 38     94FFFF            [Kr] 4d1 5s2                1.22        NaN
# 3      C2FF00                [He] 2s2                1.57        NaN
# 40     73C2C9            [Kr] 4d4 5s1                1.60        NaN
# 72     4DA6FF       [Xe] 4f14 5d3 6s2                1.50        NaN
# 75     266696       [Xe] 4f14 5d6 6s2                2.20        NaN
# 44     0A7D8C            [Kr] 4d8 5s1                2.28        NaN
# 57     FFFFC7        [Xe] 4f1 5d1 6s2                1.12        NaN
# 45       6985               [Kr] 4d10                2.20      163.0
# 22     A6A6AB            [Ar] 3d3 4s2                1.63        NaN
# 76     175487       [Xe] 4f14 5d7 6s2                2.20        NaN
# 4      FFB5B5            [He] 2s2 2p1                2.04        NaN
# 18     8F40D4                [Ar] 4s1                0.82      275.0
# 10     AB5CF2                [Ne] 3s1                0.93      227.0
# 11     8AFF00                [Ne] 3s2                1.31      173.0
# ..        ...                      ...                ...        ...
# 105    D90045       [Rn].5f14.6d4.7s2                 NaN        NaN
# 106    E00038       [Rn].5f14.6d5.7s2                 NaN        NaN
# 108    EB0026       [Rn].5f14.6d7.7s2                 NaN        NaN
# 107    E6002E       [Rn].5f14.6d6.7s2                 NaN        NaN
# 109       NaN       [Rn].5f14.6d9.7s1                 NaN        NaN
# 110       NaN      [Rn].5f14.6d10.7s1                 NaN        NaN
# 111       NaN      [Rn].5f14.6d10.7s2                 NaN        NaN
# 113       NaN  [Rn].5f14.6d10.7s2.7p2                 NaN        NaN
# 115       NaN  [Rn].5f14.6d10.7s2.7p4                 NaN        NaN
# 117       NaN  [Rn].5f14.6d10.7s2.7p6                 NaN        NaN
# 114       NaN  [Rn].5f14.6d10.7s2.7p3                 NaN        NaN
# 112       NaN  [Rn].5f14.6d10.7s2.7p1                 NaN        NaN
# 116       NaN  [Rn].5f14.6d10.7s2.7p5                 NaN        NaN
# 82     9E4FB5  [Xe] 4f14 5d10 6s2 6p3                2.02        NaN
# 49     668080       [Kr] 4d10 5s2 5p2                1.96      217.0
# 46     C0C0C0           [Kr] 4d10 5s1                1.93      172.0
# 32     BD80E3       [Ar] 3d10 4s2 4p3                2.18      185.0
# 28     C88033           [Ar] 3d10 4s1                1.90      140.0
# 26     F090A0            [Ar] 3d7 4s2                1.88        NaN
# 25     E06633            [Ar] 3d6 4s2                1.83        NaN
# 23     8A99C7            [Ar] 3d5 4s1                1.66        NaN
# 19     3DFF00                [Ar] 4s2                1.00        NaN
# 15     FFFF30            [Ne] 3s2 3p4                2.58      180.0
# 77     D0D0E0       [Xe] 4f14 5d9 6s1                2.28      175.0
# 78     FFD123      [Xe] 4f14 5d10 6s1                2.54      166.0
# 79     B8B8D0      [Xe] 4f14 5d10 6s2                2.00      155.0
# 12     BFA6A6            [Ne] 3s2 3p1                1.61        NaN
# 81     575961  [Xe] 4f14 5d10 6s2 6p2                2.33      202.0
# 5      909090            [He] 2s2 2p2                2.55      170.0
# 50     9E63B5       [Kr] 4d10 5s2 5p3                2.05        NaN
#
#      IE-1 (kJ/mol)  EA (kJ/mol)                 Oxidation States  \
# 14          1012.0        -72.0        -3, -2, -1, 1, 2, 3, 4, 5
# 8           1681.0       -328.0                               -1
# 29           906.0          0.0                                2
# 27           737.0       -112.0                   -1, 1, 2, 3, 4
# 0           1312.0        -73.0                            -1, 1
# 6           1402.0         -7.0        -3, -2, -1, 1, 2, 3, 4, 5
# 7           1314.0       -141.0                     -2, -1, 1, 2
# 24           717.0          0.0  -3, -2, -1, 1, 2, 3, 4, 5, 6, 7
# 16          1251.0       -349.0          -1, 1, 2, 3, 4, 5, 6, 7
# 41           684.0        -72.0         -2, -1, 1, 2, 3, 4, 5, 6
# 51           869.0       -190.0                   -2, 2, 4, 5, 6
# 73           770.0        -79.0         -2, -1, 1, 2, 3, 4, 5, 6
# 91           598.0          NaN                       3, 4, 5, 6
# 39           640.0        -41.0                       1, 2, 3, 4
# 37           550.0         -5.0                                2
# 21           659.0         -8.0                      -1, 2, 3, 4
# 38           600.0        -30.0                          1, 2, 3
# 3            900.0          0.0                                2
# 40           652.0        -86.0                   -1, 2, 3, 4, 5
# 72           761.0        -31.0                   -1, 2, 3, 4, 5
# 75           840.0       -106.0   -2, -1, 1, 2, 3, 4, 5, 6, 7, 8
# 44           720.0       -110.0             -1, 1, 2, 3, 4, 5, 6
# 57           534.0        -50.0                          2, 3, 4
# 45           804.0        -54.0                             2, 4
# 22           651.0        -51.0                      -1, 2, 3, 4
# 76           880.0       -151.0         -3, -1, 1, 2, 3, 4, 5, 6
# 4            801.0        -27.0                          1, 2, 3
# 18           419.0        -48.0                                1
# 10           496.0        -53.0                            -1, 1
# 11           738.0          0.0                             1, 2
# ..             ...          ...                              ...
# 105            NaN          NaN                              NaN
# 106            NaN          NaN                              NaN
# 108            NaN          NaN                              NaN
# 107            NaN          NaN                              NaN
# 109            NaN          NaN                              NaN
# 110            NaN          NaN                              NaN
# 111            NaN          NaN                              NaN
# 113            NaN          NaN                              NaN
# 115            NaN          NaN                              NaN
# 117            NaN          NaN                              NaN
# 114            NaN          NaN                              NaN
# 112            NaN          NaN                              NaN
# 116            NaN          NaN                              NaN
# 82           703.0        -91.0                         -3, 3, 5
# 49           709.0       -107.0                         -4, 2, 4
# 46           731.0       -126.0                          1, 2, 3
# 32           947.0        -78.0                      -3, 2, 3, 5
# 28           746.0       -118.0                       1, 2, 3, 4
# 26           760.0        -64.0                -1, 1, 2, 3, 4, 5
# 25           763.0        -16.0         -2, -1, 1, 2, 3, 4, 5, 6
# 23           653.0        -64.0         -2, -1, 1, 2, 3, 4, 5, 6
# 19           590.0         -2.0                                2
# 15          1000.0       -200.0         -2, -1, 1, 2, 3, 4, 5, 6
# 77           870.0       -205.0                       2, 4, 5, 6
# 78           890.0       -223.0                   -1, 1, 2, 3, 5
# 79          1007.0          0.0                          1, 2, 4
# 12           578.0        -43.0                             1, 3
# 81           716.0        -35.0                         -4, 2, 4
# 5           1087.0       -154.0       -4, -3, -2, -1, 1, 2, 3, 4
# 50           834.0       -103.0                         -3, 3, 5
#
#     StandardState       BondingType      MeltingPoint      BoilingPoint  \
# 14          solid  covalent network               317               554
# 8             gas            atomic                54                85
# 29          solid          metallic               693              1180
# 27          solid          metallic              1728              3186
# 0             gas          diatomic                14                20
# 6             gas          diatomic                63                77
# 7             gas          diatomic                55                90
# 24          solid          metallic              1519              2334
# 16            gas  covalent network               172               239
# 41          solid          metallic              2896              4912
# 51          solid          metallic               723              1261
# 73          solid          metallic              3695              5828
# 91          solid          metallic              1408              4200
# 39          solid          metallic              2128              4682
# 37          solid          metallic              1050              1655
# 21          solid          metallic              1941              3560
# 38          solid          metallic              1799              3618
# 3           solid          metallic              1560              2743
# 40          solid          metallic              2750              5017
# 72          solid          metallic              3290              5731
# 75          solid          metallic              3306              5285
# 44          solid          metallic              2237              3968
# 57          solid          metallic              1071              3633
# 45          solid          metallic              1828              3236
# 22          solid          metallic              2183              3680
# 76          solid          metallic              2739              4701
# 4           solid  covalent network              2348              4273
# 18          solid          metallic               337              1032
# 10          solid          metallic               371              1156
# 11          solid          metallic               923              1363
# ..            ...               ...               ...               ...
# 105           NaN               NaN               NaN               NaN
# 106           NaN               NaN               NaN               NaN
# 108           NaN               NaN               NaN               NaN
# 107           NaN               NaN               NaN               NaN
# 109           NaN               NaN               NaN               NaN
# 110           NaN               NaN               NaN               NaN
# 111           NaN               NaN               NaN               NaN
# 113           NaN               NaN               NaN               NaN
# 115           NaN               NaN               NaN               NaN
# 117           NaN               NaN  N/A               N/A
# 114           NaN               NaN               NaN               NaN
# 112           NaN               NaN               NaN               NaN
# 116           NaN               NaN               NaN               NaN
# 82          solid          metallic               544              1837
# 49          solid          metallic               505              2875
# 46          solid          metallic              1235              2435
# 32          solid          metallic              1090               887
# 28          solid          metallic              1358              3200
# 26          solid          metallic              1768              3200
# 25          solid          metallic              1811              3134
# 23          solid          metallic              2180              2944
# 19          solid          metallic              1115              1757
# 15          solid  covalent network               388               718
# 77          solid          metallic              2041              4098
# 78          solid          metallic              1337              3129
# 79         liquid          metallic               234               630
# 12          solid          metallic               933              2792
# 81          solid          metallic               601              2022
# 5           solid  covalent network              3823              4300
# 50          solid          metallic               904              1860
#
#               Density                  Type YearDiscovered
# 14               1.82              nonmetal           1669
# 8                   0               halogen           1670
# 29               7.14      transition metal           1746
# 27               8.91      transition metal           1751
# 0            8.99E-05              nonmetal           1766
# 6                   0              nonmetal           1772
# 7                   0              nonmetal           1774
# 24               7.47      transition metal           1774
# 16                  0               halogen           1774
# 41              10.28      transition metal           1778
# 51               6.24             metalloid           1782
# 73              19.25      transition metal           1783
# 91              19.05              actinoid           1789
# 39               6.51      transition metal           1789
# 37               2.63  alkaline earth metal           1790
# 21               4.51      transition metal           1791
# 38               4.47      transition metal           1794
# 3                1.85  alkaline earth metal           1798
# 40               8.57      transition metal           1801
# 72              16.65      transition metal           1802
# 75              22.59      transition metal           1803
# 44              12.45      transition metal           1803
# 57               6.69            lanthanoid           1803
# 45              12.02      transition metal           1803
# 22               6.11      transition metal           1803
# 76              22.56      transition metal           1803
# 4                2.46             metalloid           1807
# 18               0.86          alkali metal           1807
# 10               0.97          alkali metal           1807
# 11               1.74  alkaline earth metal           1808
# ..                ...                   ...            ...
# 105               NaN      transition metal           1974
# 106               NaN      transition metal           1976
# 108               NaN      transition metal           1982
# 107               NaN      transition metal           1984
# 109               NaN      transition metal           1994
# 110               NaN      transition metal           1994
# 111               NaN      transition metal           1996
# 113               NaN                 metal           1998
# 115               NaN             noble gas           2000
# 117  N/A               alkaline earth metal           2002
# 114               NaN               halogen           2003
# 112               NaN                 metal           2003
# 116               NaN          alkali metal           2010
# 82               9.78                 metal        Ancient
# 49               7.31                 metal        Ancient
# 46              10.49      transition metal        Ancient
# 32               5.73             metalloid        Ancient
# 28               8.92      transition metal        Ancient
# 26                8.9      transition metal        Ancient
# 25               7.87      transition metal        Ancient
# 23               7.14      transition metal        Ancient
# 19               1.55  alkaline earth metal        Ancient
# 15               1.96              nonmetal        Ancient
# 77              21.09      transition metal        Ancient
# 78               19.3      transition metal        Ancient
# 79              13.53      transition metal        Ancient
# 12                2.7                 metal        Ancient
# 81              11.34                 metal        Ancient
# 5                2.26              nonmetal        Ancient
# 50                6.7             metalloid        Ancient
#
# [118 rows x 20 columns]

# %% [markdown]
# ## Part Three
# Take a look at the data table above.
# - Can you tell which element was discovered first?
# - Can you sort the table alphabetically? Or reverse alphabetically?
# - Which elements have the smallest and largest ionic radius?

# %% [markdown]
# ---
# ## Saving Your Work
# This is running on a Google Compute Engine server on a distant planet and deletes what you've done after 20 minutes of inactivity. To save for later use or analysis you have a few options:
# - File > Download as > ipynb (to continue your analysis later)
# - File > Download as > pdf (static copy including code and graphs)
# - Right-click on a graph and select Save Image As ... (to share a pic)
#
# ## Credits
# The data came from Penn State CS professor [Doug Hogan](http://php.scripts.psu.edu/djh300/cmpsc221/p3s11-pt-data.htm). UCF undergraduates Sam Borges, who located the data, and Lissa Galguera, who formatted it, were funded by Seminole County Schools to make scientific computing a standard part of every middle school science class.
# This notebook was designed by Adam LaMee, who coordinated its development as the [PhysTEC](https://www.phystec.org/) Teacher-in-residence in the [University of Central Florida's Physics department](https://sciences.ucf.edu/physics/). Find more activities and license info at [CODINGinK12.org](http://www.codingink12.org). Finally, thanks to the great folks at [MyBinder.org](https://beta.mybinder.org/) this notebook is interactive without you needing to download it or install Jupyter on your own device.
